# %%
#importing libraries
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.colors as colors
import matplotlib.pyplot as plt

# %%
#loading the well log data file
train_data=pd.read_csv('train.csv',sep=';')

# %%
#let's have a look at the data
train_data.head()
# Out:
#       WELL  DEPTH_MD         X_LOC      Y_LOC       Z_LOC         GROUP  \
# 0  15/9-13   494.528  437641.96875  6470972.5 -469.501831  NORDLAND GP.
# 1  15/9-13   494.680  437641.96875  6470972.5 -469.653809  NORDLAND GP.
# 2  15/9-13   494.832  437641.96875  6470972.5 -469.805786  NORDLAND GP.
# 3  15/9-13   494.984  437641.96875  6470972.5 -469.957794  NORDLAND GP.
# 4  15/9-13   495.136  437641.96875  6470972.5 -470.109772  NORDLAND GP.
#
#   FORMATION       CALI  RSHA      RMED  ...        ROP  DTS  DCAL      DRHO  \
# 0       NaN  19.480835   NaN  1.611410  ...  34.636410  NaN   NaN -0.574928
# 1       NaN  19.468800   NaN  1.618070  ...  34.636410  NaN   NaN -0.570188
# 2       NaN  19.468800   NaN  1.626459  ...  34.779556  NaN   NaN -0.574245
# 3       NaN  19.459282   NaN  1.621594  ...  39.965164  NaN   NaN -0.586315
# 4       NaN  19.453100   NaN  1.602679  ...  57.483765  NaN   NaN -0.597914
#
#    MUDWEIGHT  RMIC  ROPA  RXO  FORCE_2020_LITHOFACIES_LITHOLOGY  \
# ...

# %%
train_data.tail()
# Out:
#             WELL   DEPTH_MD  X_LOC  Y_LOC  Z_LOC         GROUP  FORMATION  \
# 1170506  7/1-2 S  3169.3124    NaN    NaN    NaN  VESTLAND GP.  Bryne Fm.
# 1170507  7/1-2 S  3169.4644    NaN    NaN    NaN  VESTLAND GP.  Bryne Fm.
# 1170508  7/1-2 S  3169.6164    NaN    NaN    NaN  VESTLAND GP.  Bryne Fm.
# 1170509  7/1-2 S  3169.7684    NaN    NaN    NaN  VESTLAND GP.  Bryne Fm.
# 1170510  7/1-2 S  3169.9204    NaN    NaN    NaN  VESTLAND GP.  Bryne Fm.
#
#              CALI  RSHA  RMED  ...        ROP  DTS  DCAL      DRHO  MUDWEIGHT  \
# 1170506  8.423170   NaN   NaN  ...  27.674368  NaN   NaN -0.001763        NaN
# 1170507  8.379244   NaN   NaN  ...  28.024338  NaN   NaN -0.007600        NaN
# 1170508  8.350248   NaN   NaN  ...  28.091282  NaN   NaN -0.018297        NaN
# 1170509  8.313779   NaN   NaN  ...  28.019775  NaN   NaN -0.011438        NaN
# 1170510  8.294910   NaN   NaN  ...  25.985943  NaN   NaN -0.011398        NaN
#
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170511 entries, 0 to 1170510
# Data columns (total 29 columns):
# WELL                                 1170511 non-null object
# DEPTH_MD                             1170511 non-null float64
# X_LOC                                1159736 non-null float64
# Y_LOC                                1159736 non-null float64
# Z_LOC                                1159736 non-null float64
# GROUP                                1169233 non-null object
# FORMATION                            1033517 non-null object
# CALI                                 1082634 non-null float64
# RSHA                                 630650 non-null float64
# RMED                                 1131518 non-null float64
# RDEP                                 1159496 non-null float64
# RHOB                                 1009242 non-null float64
# GR                                   1170511 non-null float64
# ...

# %%
train_data.describe()
# Out:
#            DEPTH_MD         X_LOC         Y_LOC         Z_LOC          CALI  \
# count  1.170511e+06  1.159736e+06  1.159736e+06  1.159736e+06  1.082634e+06
# mean   2.184087e+03  4.856310e+05  6.681276e+06 -2.138527e+03  1.318568e+01
# std    9.971821e+02  3.455641e+04  1.281524e+05  9.709426e+02  3.798907e+00
# min    1.360860e+02  4.268988e+05  6.406641e+06 -5.395563e+03  2.344000e+00
# 25%    1.418597e+03  4.547996e+05  6.591327e+06 -2.811502e+03  9.429712e+00
# 50%    2.076605e+03  4.769203e+05  6.737311e+06 -2.042785e+03  1.255575e+01
# 75%    2.864393e+03  5.201532e+05  6.784886e+06 -1.391866e+03  1.671075e+01
# max    5.436632e+03  5.726328e+05  6.856661e+06 -1.110860e+02  2.827900e+01
#
#                 RSHA          RMED          RDEP          RHOB            GR  \
# count  630650.000000  1.131518e+06  1.159496e+06  1.009242e+06  1.170511e+06
# mean       10.694664  4.986978e+00  1.069103e+01  2.284987e+00  7.091370e+01
# ...

# %%
#add two more columns to the dataset, one with a different integer label and the second column with a text label with the correspoding lithology name.
# map of lithology to text label
litho_keys = {30000: 'Sandstone',
                     65030: 'Sandstone/Shale',
                     65000: 'Shale',
                     80000: 'Marl',
                     74000: 'Dolomite',
                     70000: 'Limestone',
                     70032: 'Chalk',
                     88000: 'Halite',
                     86000: 'Anhydrite',
                     99000: 'Tuff',
                     90000: 'Coal',
                     93000: 'Basement'}
    
# map of lithology to integer label
litho_numbers = {30000: 0,
             65030: 1,
             65000: 2,
             80000: 3,
             74000: 4,
             70000: 5,
             70032: 6,
             88000: 7,
             86000: 8,
             99000: 9,
             90000: 10,
             93000: 11}

# generation of the two new columns
train_data['LITHOLOGY'] = train_data['FORCE_2020_LITHOFACIES_LITHOLOGY'].map(litho_keys)
train_data['LITH_LABEL'] = train_data['FORCE_2020_LITHOFACIES_LITHOLOGY'].map(litho_numbers)

# %%
corr_matrix=train_data.corr()
abs(corr_matrix['LITH_LABEL'].sort_values())
# Out:
# GR                                  0.076800
# DEPTH_MD                            0.008784
# FORCE_2020_LITHOFACIES_LITHOLOGY    0.746194
# LITH_LABEL                          1.000000
# Name: LITH_LABEL, dtype: float64

# %%
train_data.head()
# Out:
#       WELL  DEPTH_MD         X_LOC      Y_LOC       Z_LOC         GROUP  \
# 0  15/9-13   494.528  437641.96875  6470972.5 -469.501831  NORDLAND GP.
# 1  15/9-13   494.680  437641.96875  6470972.5 -469.653809  NORDLAND GP.
# 2  15/9-13   494.832  437641.96875  6470972.5 -469.805786  NORDLAND GP.
# 3  15/9-13   494.984  437641.96875  6470972.5 -469.957794  NORDLAND GP.
# 4  15/9-13   495.136  437641.96875  6470972.5 -470.109772  NORDLAND GP.
#
#   FORMATION       CALI  RSHA      RMED  ...  DCAL      DRHO  MUDWEIGHT  RMIC  \
# 0       NaN  19.480835   NaN  1.611410  ...   NaN -0.574928        NaN   NaN
# 1       NaN  19.468800   NaN  1.618070  ...   NaN -0.570188        NaN   NaN
# 2       NaN  19.468800   NaN  1.626459  ...   NaN -0.574245        NaN   NaN
# 3       NaN  19.459282   NaN  1.621594  ...   NaN -0.586315        NaN   NaN
# 4       NaN  19.453100   NaN  1.602679  ...   NaN -0.597914        NaN   NaN
#
#    ROPA  RXO  FORCE_2020_LITHOFACIES_LITHOLOGY  \
# ...

# %%
train_data.dropna(axis=1,inplace=True)

# %%
train_data
# Out:
#             WELL   DEPTH_MD         GR  FORCE_2020_LITHOFACIES_LITHOLOGY  \
# 0        15/9-13   494.5280  80.200851                             65000
# 1        15/9-13   494.6800  79.262886                             65000
# 2        15/9-13   494.8320  74.821999                             65000
# 3        15/9-13   494.9840  72.878922                             65000
# 4        15/9-13   495.1360  71.729141                             65000
# ...          ...        ...        ...                               ...
# 1170506  7/1-2 S  3169.3124  77.654900                             30000
# 1170507  7/1-2 S  3169.4644  75.363937                             65030
# 1170508  7/1-2 S  3169.6164  66.452843                             65030
# 1170509  7/1-2 S  3169.7684  55.784817                             65030
# 1170510  7/1-2 S  3169.9204  48.432129                             65030
#
#                LITHOLOGY  LITH_LABEL
# 0                  Shale           2
# ...

# %%
print(train_data)
# Out:
#             WELL   DEPTH_MD         GR  FORCE_2020_LITHOFACIES_LITHOLOGY  \
# 0        15/9-13   494.5280  80.200851                             65000
# 1        15/9-13   494.6800  79.262886                             65000
# 2        15/9-13   494.8320  74.821999                             65000
# 3        15/9-13   494.9840  72.878922                             65000
# 4        15/9-13   495.1360  71.729141                             65000
# ...          ...        ...        ...                               ...
# 1170506  7/1-2 S  3169.3124  77.654900                             30000
# 1170507  7/1-2 S  3169.4644  75.363937                             65030
# 1170508  7/1-2 S  3169.6164  66.452843                             65030
# 1170509  7/1-2 S  3169.7684  55.784817                             65030
# 1170510  7/1-2 S  3169.9204  48.432129                             65030
#
#                LITHOLOGY  LITH_LABEL
# 0                  Shale           2
# ...

# %%
train_data.head()
# Out:
#       WELL  DEPTH_MD         GR  FORCE_2020_LITHOFACIES_LITHOLOGY LITHOLOGY  \
# 0  15/9-13   494.528  80.200851                             65000     Shale
# 1  15/9-13   494.680  79.262886                             65000     Shale
# 2  15/9-13   494.832  74.821999                             65000     Shale
# 3  15/9-13   494.984  72.878922                             65000     Shale
# 4  15/9-13   495.136  71.729141                             65000     Shale
#
#    LITH_LABEL
# 0           2
# 1           2
# 2           2
# 3           2
# 4           2

# %%
well=pd.read_csv('train.csv',sep=";")

# %%
well
# Out:
#             WELL   DEPTH_MD         X_LOC      Y_LOC       Z_LOC  \
# 0        15/9-13   494.5280  437641.96875  6470972.5 -469.501831
# 1        15/9-13   494.6800  437641.96875  6470972.5 -469.653809
# 2        15/9-13   494.8320  437641.96875  6470972.5 -469.805786
# 3        15/9-13   494.9840  437641.96875  6470972.5 -469.957794
# 4        15/9-13   495.1360  437641.96875  6470972.5 -470.109772
# ...          ...        ...           ...        ...         ...
# 1170506  7/1-2 S  3169.3124           NaN        NaN         NaN
# 1170507  7/1-2 S  3169.4644           NaN        NaN         NaN
# 1170508  7/1-2 S  3169.6164           NaN        NaN         NaN
# 1170509  7/1-2 S  3169.7684           NaN        NaN         NaN
# 1170510  7/1-2 S  3169.9204           NaN        NaN         NaN
#
#                 GROUP  FORMATION       CALI  RSHA      RMED  ...        ROP  \
# 0        NORDLAND GP.        NaN  19.480835   NaN  1.611410  ...  34.636410
# ...

# %%
well.count()
# Out:
# WELL                                 1170511
# DEPTH_MD                             1170511
# X_LOC                                1159736
# Y_LOC                                1159736
# Z_LOC                                1159736
# GROUP                                1169233
# FORMATION                            1033517
# CALI                                 1082634
# RSHA                                  630650
# RMED                                 1131518
# RDEP                                 1159496
# RHOB                                 1009242
# GR                                   1170511
# SGR                                    69353
# NPHI                                  765409
# PEF                                   671692
# DTC                                  1089648
# SP                                    864247
# BS                                    682657
# ROP                                   535071
# DTS                                   174613
# ...

# %%
rewell=well.drop(['WELL','GROUP','FORMATION','RSHA','RHOB','SGR','NPHI','PEF','SP','BS','ROP','DTS','DCAL','DRHO','MUDWEIGHT','RMIC','ROPA','RXO'], axis=1)
rewell
# Out:
#           DEPTH_MD         X_LOC      Y_LOC       Z_LOC       CALI      RMED  \
# 0         494.5280  437641.96875  6470972.5 -469.501831  19.480835  1.611410
# 1         494.6800  437641.96875  6470972.5 -469.653809  19.468800  1.618070
# 2         494.8320  437641.96875  6470972.5 -469.805786  19.468800  1.626459
# 3         494.9840  437641.96875  6470972.5 -469.957794  19.459282  1.621594
# 4         495.1360  437641.96875  6470972.5 -470.109772  19.453100  1.602679
# ...            ...           ...        ...         ...        ...       ...
# 1170506  3169.3124           NaN        NaN         NaN   8.423170       NaN
# 1170507  3169.4644           NaN        NaN         NaN   8.379244       NaN
# 1170508  3169.6164           NaN        NaN         NaN   8.350248       NaN
# 1170509  3169.7684           NaN        NaN         NaN   8.313779       NaN
# 1170510  3169.9204           NaN        NaN         NaN   8.294910       NaN
#
# ...

# %%
rewell.count()
# Out:
# DEPTH_MD                             1170511
# X_LOC                                1159736
# Y_LOC                                1159736
# Z_LOC                                1159736
# CALI                                 1082634
# RMED                                 1131518
# RDEP                                 1159496
# GR                                   1170511
# DTC                                  1089648
# FORCE_2020_LITHOFACIES_LITHOLOGY     1170511
# FORCE_2020_LITHOFACIES_CONFIDENCE    1170332
# dtype: int64

# %%
rewell=rewell.dropna()

# %%
rewell
# Out:
#           DEPTH_MD         X_LOC      Y_LOC        Z_LOC       CALI      RMED  \
# 0         494.5280  437641.96875  6470972.5  -469.501831  19.480835  1.611410
# 1         494.6800  437641.96875  6470972.5  -469.653809  19.468800  1.618070
# 2         494.8320  437641.96875  6470972.5  -469.805786  19.468800  1.626459
# 3         494.9840  437641.96875  6470972.5  -469.957794  19.459282  1.621594
# 4         495.1360  437641.96875  6470972.5  -470.109772  19.453100  1.602679
# ...            ...           ...        ...          ...        ...       ...
# 1170442  3159.5844  444920.37500  6421578.5 -3098.725830   8.420886  0.789877
# 1170443  3159.7364  444920.37500  6421578.5 -3098.877441   8.428133  0.815565
# 1170444  3159.8884  444920.37500  6421578.5 -3099.029541   8.409408  0.859699
# 1170445  3160.0404  444920.37500  6421578.5 -3099.181396   8.400051  0.885569
# 1170446  3160.1924  444920.37500  6421578.5 -3099.333496   8.429921  0.880490
#
# ...

# %%
rewell.count()
# Out:
# DEPTH_MD                             1008719
# X_LOC                                1008719
# Y_LOC                                1008719
# Z_LOC                                1008719
# CALI                                 1008719
# RMED                                 1008719
# RDEP                                 1008719
# GR                                   1008719
# DTC                                  1008719
# FORCE_2020_LITHOFACIES_LITHOLOGY     1008719
# FORCE_2020_LITHOFACIES_CONFIDENCE    1008719
# dtype: int64

# %%
#add two more columns to the dataset, one with a different integer label and the second column with a text label with the correspoding lithology name.
# map of lithology to text label
litho_keys = {30000: 'Sandstone',
                     65030: 'Sandstone/Shale',
                     65000: 'Shale',
                     80000: 'Marl',
                     74000: 'Dolomite',
                     70000: 'Limestone',
                     70032: 'Chalk',
                     88000: 'Halite',
                     86000: 'Anhydrite',
                     99000: 'Tuff',
                     90000: 'Coal',
                     93000: 'Basement'}
    
# map of lithology to integer label
litho_numbers = {30000: 0,
             65030: 1,
             65000: 2,
             80000: 3,
             74000: 4,
             70000: 5,
             70032: 6,
             88000: 7,
             86000: 8,
             99000: 9,
             90000: 10,
             93000: 11}

# generation of the two new columns
rewell['LITHOLOGY'] = rewell['FORCE_2020_LITHOFACIES_LITHOLOGY'].map(litho_keys)
rewell['LITHO_NUMBER'] = rewell['FORCE_2020_LITHOFACIES_LITHOLOGY'].map(litho_numbers)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
rewell
# Out:
#           DEPTH_MD         X_LOC      Y_LOC        Z_LOC       CALI      RMED  \
# 0         494.5280  437641.96875  6470972.5  -469.501831  19.480835  1.611410
# 1         494.6800  437641.96875  6470972.5  -469.653809  19.468800  1.618070
# 2         494.8320  437641.96875  6470972.5  -469.805786  19.468800  1.626459
# 3         494.9840  437641.96875  6470972.5  -469.957794  19.459282  1.621594
# 4         495.1360  437641.96875  6470972.5  -470.109772  19.453100  1.602679
# ...            ...           ...        ...          ...        ...       ...
# 1170442  3159.5844  444920.37500  6421578.5 -3098.725830   8.420886  0.789877
# 1170443  3159.7364  444920.37500  6421578.5 -3098.877441   8.428133  0.815565
# 1170444  3159.8884  444920.37500  6421578.5 -3099.029541   8.409408  0.859699
# 1170445  3160.0404  444920.37500  6421578.5 -3099.181396   8.400051  0.885569
# 1170446  3160.1924  444920.37500  6421578.5 -3099.333496   8.429921  0.880490
#
# ...

# %%
def plot_logs(data):
    #sort data by depth
    data = data.sort_values(by = 'DEPTH_MD')
    f, ax = plt.subplots(nrows=1, ncols=5, figsize=(18, 12))
    ax[0].plot(data['CALI'], data['DEPTH_MD'], '-g')
    ax[1].plot(data['RMED'], data['DEPTH_MD'], '-b')
    ax[2].plot(data['RDEP'], data['DEPTH_MD'], '-', color='0.5')
    ax[3].plot(data['GR'], data['DEPTH_MD'], '-', color='r')
    ax[4].plot(data['DTC'], data['DEPTH_MD'], '-', color='black')
    
    #lets add labels for the x-axis
    ax[0].set_xlabel("CALI")
    ax[0].set_xlim(data['CALI'].min(),data['CALI'].max())
    ax[1].set_xlabel("RMED")
    ax[1].set_xlim(data['RMED'].min(),data['RMED'].max())
    ax[2].set_xlabel("RDEP")
    ax[2].set_xlim(data['RDEP'].min(),data['RDEP'].max())
    ax[3].set_xlabel("GR")
    ax[3].set_xlim(data['GR'].min(),data['GR'].max())
    ax[4].set_xlabel("DTC")
    ax[4].set_xlim(data['DTC'].min(),data['DTC'].max())

    #add label to the y-axis
    ax[0].set_ylabel('DEPTH_MD')

# %%
plot_logs(rewell)

# %%
import seaborn as sns

# %%
#visualizing the count of each lithology number
fig = plt.figure(figsize = (20,10))
plot = sns.countplot(x="LITHO_NUMBER", data=rewell)

# %%
#importing required librarires
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.utils import shuffle
from sklearn.metrics import classification_report, accuracy_score
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier

# %%
test_data=pd.read_csv('test.csv',sep=';')

# %%
test_data
# Out:
#            WELL     DEPTH_MD         X_LOC      Y_LOC        Z_LOC  \
# 0       15/9-14   480.628001  423244.50000  6461862.5  -455.624420
# 1       15/9-14   480.780001  423244.50000  6461862.5  -455.776428
# 2       15/9-14   480.932001  423244.50000  6461862.5  -455.928436
# 3       15/9-14   481.084001  423244.50000  6461862.5  -456.080444
# 4       15/9-14   481.236001  423244.53125  6461862.5  -456.232422
# ...         ...          ...           ...        ...          ...
# 136781   35/9-8  3224.389600  536225.93750  6794880.5 -3199.876465
# 136782   35/9-8  3224.541600  536225.93750  6794880.5 -3200.028320
# 136783   35/9-8  3224.693600  536225.93750  6794880.5 -3200.180176
# 136784   35/9-8  3224.845600  536225.93750  6794880.5 -3200.332031
# 136785   35/9-8  3224.997600  536225.93750  6794880.5 -3200.483887
#
#                GROUP    FORMATION     CALI  RSHA      RMED  ...         SP  \
# 0       NORDLAND GP.          NaN  19.2031   NaN  1.613886  ...  35.525719
# ...

# %%
test_data.count()
# Out:
# WELL         136786
# DEPTH_MD     136786
# X_LOC        136727
# Y_LOC        136727
# Z_LOC        136727
# GROUP        136786
# FORMATION    129712
# CALI         131141
# RSHA          39097
# RMED         136199
# RDEP         136727
# RHOB         119826
# GR           136786
# SGR               0
# NPHI         104043
# PEF          113503
# DTC          135963
# SP            66627
# BS            66964
# ROP           68316
# DTS           43220
# DCAL          13515
# DRHO         111556
# MUDWEIGHT     20269
# RMIC          11316
# ROPA          55790
# RXO           29848
# dtype: int64

# %%
test_data=test_data.drop(['GROUP','FORMATION','RSHA','RHOB','SGR','NPHI','PEF','SP','BS','ROP','DTS','DCAL','DRHO','MUDWEIGHT','RMIC','ROPA','RXO'], axis=1)
test_data
# Out:
#            WELL     DEPTH_MD         X_LOC      Y_LOC        Z_LOC     CALI  \
# 0       15/9-14   480.628001  423244.50000  6461862.5  -455.624420  19.2031
# 1       15/9-14   480.780001  423244.50000  6461862.5  -455.776428  19.2031
# 2       15/9-14   480.932001  423244.50000  6461862.5  -455.928436  19.2031
# 3       15/9-14   481.084001  423244.50000  6461862.5  -456.080444  19.2031
# 4       15/9-14   481.236001  423244.53125  6461862.5  -456.232422  19.2031
# ...         ...          ...           ...        ...          ...      ...
# 136781   35/9-8  3224.389600  536225.93750  6794880.5 -3199.876465   8.4978
# 136782   35/9-8  3224.541600  536225.93750  6794880.5 -3200.028320   8.4978
# 136783   35/9-8  3224.693600  536225.93750  6794880.5 -3200.180176   8.4978
# 136784   35/9-8  3224.845600  536225.93750  6794880.5 -3200.332031   8.4978
# 136785   35/9-8  3224.997600  536225.93750  6794880.5 -3200.483887   8.4978
#
#             RMED      RDEP         GR         DTC
# ...

# %%
test_data.dropna()
# Out:
#            WELL     DEPTH_MD         X_LOC      Y_LOC        Z_LOC     CALI  \
# 0       15/9-14   480.628001  423244.50000  6461862.5  -455.624420  19.2031
# 1       15/9-14   480.780001  423244.50000  6461862.5  -455.776428  19.2031
# 2       15/9-14   480.932001  423244.50000  6461862.5  -455.928436  19.2031
# 3       15/9-14   481.084001  423244.50000  6461862.5  -456.080444  19.2031
# 4       15/9-14   481.236001  423244.53125  6461862.5  -456.232422  19.2031
# ...         ...          ...           ...        ...          ...      ...
# 136781   35/9-8  3224.389600  536225.93750  6794880.5 -3199.876465   8.4978
# 136782   35/9-8  3224.541600  536225.93750  6794880.5 -3200.028320   8.4978
# 136783   35/9-8  3224.693600  536225.93750  6794880.5 -3200.180176   8.4978
# 136784   35/9-8  3224.845600  536225.93750  6794880.5 -3200.332031   8.4978
# 136785   35/9-8  3224.997600  536225.93750  6794880.5 -3200.483887   8.4978
#
#             RMED      RDEP         GR         DTC
# ...

# %%
x_data = rewell.drop(columns = ['LITHO_NUMBER','LITHOLOGY','FORCE_2020_LITHOFACIES_LITHOLOGY','FORCE_2020_LITHOFACIES_CONFIDENCE'])
y_data = rewell['LITHO_NUMBER']

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.2, random_state = 42)

# %%
#Decision Tree Model

DTclassifier = DecisionTreeClassifier(criterion='entropy', max_depth=1000)

DTclassifier.fit(x_train, y_train)
y_pred_DT = DTclassifier.predict(x_test)

# %%
print(classification_report(y_test, y_pred_DT))
print('best accuracy score by Decision Tree is', accuracy_score(y_test, y_pred_DT))
dt_accuracy = accuracy_score(y_test, y_pred_DT)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92     30127
#            1       0.86      0.87      0.87     26326
#            2       0.96      0.96      0.96    123717
#            3       0.91      0.91      0.91      5908
#            4       0.62      0.53      0.57       281
#            5       0.85      0.83      0.84     10557
#            6       0.96      0.96      0.96      1716
#            7       0.86      0.75      0.80         8
#            8       0.95      0.98      0.97        61
#            9       0.93      0.93      0.93      2299
#           10       0.70      0.68      0.69       725
#           11       1.00      1.00      1.00        19
#
#     accuracy                           0.93    201744
#    macro avg       0.88      0.86      0.87    201744
# weighted avg       0.93      0.93      0.93    201744
#
# best accuracy score by Decision Tree is 0.9335742326909351

# %%
#add two more columns to the dataset, one with a different integer label and the second column with a text label with the correspoding lithology name.
# map of lithology to text label
litho_keys = {30000: 'Sandstone',
                     65030: 'Sandstone/Shale',
                     65000: 'Shale',
                     80000: 'Marl',
                     74000: 'Dolomite',
                     70000: 'Limestone',
                     70032: 'Chalk',
                     88000: 'Halite',
                     86000: 'Anhydrite',
                     99000: 'Tuff',
                     90000: 'Coal',
                     93000: 'Basement'}
    
# map of lithology to integer label
litho_numbers = {30000: 0,
             65030: 1,
             65000: 2,
             80000: 3,
             74000: 4,
             70000: 5,
             70032: 6,
             88000: 7,
             86000: 8,
             99000: 9,
             90000: 10,
             93000: 11}

# generation of the two new columns
well['LITHOLOGY'] = well['FORCE_2020_LITHOFACIES_LITHOLOGY'].map(litho_keys)
well['LITH_LABEL'] = well['FORCE_2020_LITHOFACIES_LITHOLOGY'].map(litho_numbers)

# %%
from pandas.plotting import scatter_matrix

# %%
attributes=["CALI","RSHA","RMED","RDEP","RHOB","GR","NPHI","PEF","DTC","SP","BS","FORCE_2020_LITHOFACIES_LITHOLOGY"]

# %%
scatter_matrix(well[attributes],figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000009DC83BDCC8>,
# ...
#       dtype=object)

# %%
corr_matrix=well.corr()

# %%
abs(corr_matrix["LITH_LABEL"].sort_values(ascending=False))
# Out:
# LITH_LABEL                          1.000000
# FORCE_2020_LITHOFACIES_LITHOLOGY    0.746194
# DEPTH_MD                            0.008784
# GR                                  0.076800
# Name: LITH_LABEL, dtype: float64

# %%
abs(corr_matrix['RSHA'].sort_values())
# Out:
# NPHI                                 0.151975
# DTC                                  0.134724
# DTS                                  0.134674
# Z_LOC                                0.096993
# GR                                   0.074280
# BS                                   0.039913
# ROPA                                 0.036224
# SP                                   0.030157
# Y_LOC                                0.022042
# SGR                                  0.013331
# DRHO                                 0.012619
# CALI                                 0.011651
# PEF                                  0.011581
# ROP                                  0.008611
# DCAL                                 0.000492
# X_LOC                                0.004157
# FORCE_2020_LITHOFACIES_CONFIDENCE    0.012168
# MUDWEIGHT                            0.044724
# FORCE_2020_LITHOFACIES_LITHOLOGY     0.059277
# RXO                                  0.062877
# ...

# %%
abs(well.corr()['FORCE_2020_LITHOFACIES_LITHOLOGY'][abs(well.corr()['FORCE_2020_LITHOFACIES_LITHOLOGY'])>0.08].drop('FORCE_2020_LITHOFACIES_LITHOLOGY')).index.tolist()
# Out:
# ['RDEP', 'GR', 'SGR', 'NPHI', 'DTS', 'FORCE_2020_LITHOFACIES_CONFIDENCE']

# %%
well.corr()
# Out:
#                                    DEPTH_MD     X_LOC     Y_LOC     Z_LOC  \
# DEPTH_MD                           1.000000 -0.078266  0.258393 -0.994761
# X_LOC                             -0.078266  1.000000  0.417225  0.086620
# Y_LOC                              0.258393  0.417225  1.000000 -0.251269
# Z_LOC                             -0.994761  0.086620 -0.251269  1.000000
# CALI                              -0.583351 -0.119089 -0.088677  0.577283
# RSHA                               0.090240  0.004157 -0.022042 -0.096993
# RMED                               0.055476  0.012867  0.030189 -0.040089
# RDEP                               0.051349  0.071869 -0.085301 -0.053246
# RHOB                               0.741904  0.086809  0.205928 -0.743765
# GR                                 0.098282  0.232408  0.192176 -0.088711
# SGR                               -0.152282  0.061186  0.097496  0.152966
# NPHI                              -0.544272 -0.108616 -0.095656  0.551328
# ...
